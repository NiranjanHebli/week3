# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/niranjanhebli/Desktop/Week3/week3/.venv/lib/python3.9/site-packages (2.3.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/niranjanhebli/Desktop/Week3/week3/.venv/lib/python3.9/site-packages (from pandas) (2026.1.post1)
# Requirement already satisfied: numpy>=1.22.4 in /Users/niranjanhebli/Desktop/Week3/week3/.venv/lib/python3.9/site-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/niranjanhebli/Desktop/Week3/week3/.venv/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/niranjanhebli/Desktop/Week3/week3/.venv/lib/python3.9/site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in /Users/niranjanhebli/Desktop/Week3/week3/.venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Users/niranjanhebli/Desktop/Week3/week3/.venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

def analyze_csv(filepath):
    # Load CSV
    df = pd.read_csv(filepath)
    
    # Basic info
    num_rows, num_cols = df.shape
    
    # Identify column types
    numeric_cols = df.select_dtypes(include='number').columns.tolist()
    categorical_cols = df.select_dtypes(exclude='number').columns.tolist()
    
    # Null values
    null_counts = df.isnull().sum().to_dict()
    
    # Memory usage in MB
    memory_mb = df.memory_usage(deep=True).sum() / (1024**2)
    
    # Summary
    print("FIRST 5 MINUTES CHECKLIST")
    print("-------------------------")
    print("Shape:", df.shape)
    print("\nColumns:")
    print(df.columns.tolist())
    
    print("\nFirst 5 rows:")
    print(df.head())
    
    print("\nData types:")
    print(df.dtypes)
    
    print("\nMissing values:")
    print(df.isnull().sum())
    
    print("\nMemory usage (MB):", round(memory_mb, 2))
    
    # Return summary dictionary
    return {
        "num_rows": num_rows,
        "num_cols": num_cols,
        "numeric_cols": numeric_cols,
        "categorical_cols": categorical_cols,
        "null_counts": null_counts,
        "memory_mb": round(memory_mb, 2)
    }

# %%
summary = analyze_csv("data.csv")
print(summary)
# Out:
# FIRST 5 MINUTES CHECKLIST
# -------------------------
# Shape: (20, 5)
#
# Columns:
# ['order_id', 'customer_name', 'city', 'order_amount', 'delivery_time_min']
#
# First 5 rows:
#    order_id customer_name       city  order_amount  delivery_time_min
# 0         1          Amit     Mumbai           250                 25
# 1         2          Riya      Delhi           340                 30
# 2         3         Rahul  Bangalore           120                 28
# 3         4         Sneha     Mumbai           560                 40
# 4         5        Vikram       Pune           430                 35
#
# Data types:
# order_id              int64
# customer_name        object
# city                 object
# order_amount          int64
# delivery_time_min     int64
# dtype: object
#
# Missing values:
# order_id             0
# customer_name        0
# city                 0
# order_amount         0
# delivery_time_min    0
# dtype: int64
#
# Memory usage (MB): 0.0
# {'num_rows': 20, 'num_cols': 5, 'numeric_cols': ['order_id', 'order_amount', 'delivery_time_min'], 'categorical_cols': ['customer_name', 'city'], 'null_counts': {'order_id': 0, 'customer_name': 0, 'city': 0, 'order_amount': 0, 'delivery_time_min': 0}, 'memory_mb': np.float64(0.0)}
